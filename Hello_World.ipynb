# %%
print("Hello World!")

# %%
def print_even( ):
    for x in range(10):
        if x % 2 == 0:
            print(x)

print_even()

# %%
a = 20
b = 30 
print(a + b)

# %%
tup = ['apple','mango','orange']
print(tup)
print(type(tup))
print(tup[0])
print(tup[1])
print(tup[2])

# %%
dict = {'name':'John', 'age':20, 'salary':2000}
print(dict)
print(type(dict))
print(dict['name'])
print(dict['age'])
print(dict['salary'])

# %%
df = spark.table("products")
display(df)

# %%
df.count()
